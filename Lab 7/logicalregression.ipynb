# %%
from sklearn.linear_model import LogisticRegression
import numpy as np
X = np.array([[1], [2], [3], [4], [5], [6], [7], [8]])
y = np.array([0, 0, 0, 0, 1, 1, 1, 1])
model = LogisticRegression()
model.fit(X, y)
prediction = model.predict([[5]])
print("Coefficient :", model.coef_[0][0])
print("Intercept :", model.intercept_[0])
print("Prediction :", prediction[0])
# Out:
# Coefficient : 1.1697993675705605
# Intercept : -5.264107913297968
# Prediction : 1

# %%
from sklearn.linear_model import Lasso
import numpy as np
X = np.array([[1], [2], [3], [4], [5], [6]])
y = np.array([2, 4, 6, 8, 10, 12])
model = Lasso(alpha=0.1)
model.fit(X, y)
prediction = model.predict([[7]])
print("Coefficient :", model.coef_[0])
print("Intercept   :", model.intercept_)
print("Prediction  :", prediction[0])
# Out:
# Coefficient : 1.9657142857142855
# Intercept   : 0.120000000000001
# Prediction  : 13.879999999999999

# %%
from sklearn.linear_model import Ridge 
import numpy as np
X = np.array([[1], [2], [3], [4], [5], [6]])
y = np.array([2, 4, 6, 8, 10, 12])
model = Ridge(alpha=0.1)
model.fit(X, y)
prediction =  model.predict([[7]])
print("Coefficient : ", model.coef_[0])
print("Intercept : ", model.intercept_)
print("Prediction : ", prediction[0])
# Out:
# Coefficient :  1.9886363636363633
# Intercept :  0.0397727272727284
# Prediction :  13.960227272727272

# %%
from sklearn.linear_model import ElasticNet
import numpy as np
X = np.array([[1], [2], [3], [4], [5], [6]])
y = np.array([2, 4, 6, 8, 10, 12])
model = ElasticNet(alpha=0.1, l1_ratio = 0.5)
model.fit(X, y)
prediction =  model.predict([[7]])
print("Coefficient : ", model.coef_[0])
print("Intercept : ", model.intercept_)
print("Prediction : ", prediction[0])
# Out:
# Coefficient :  1.949438202247191
# Intercept :  0.17696629213483117
# Prediction :  13.823033707865168

# %%
from sklearn.metrics import mean_squared_error
actual = [10,20,30,40]
predicted = [12,18,29,42]
mse = mean_squared_error(actual , predicted)
print("Mean Squared Error : ", mse)
# Out:
# Mean Squared Error :  3.25

# %%
from sklearn.metrics import mean_absolute_error
actual = [10,20,30,40]
predicted = [12,18,29,42]
mae = mean_absolute_error(actual , predicted)
print("Mean Absolute Error : ", mae)
# Out:
# Mean Absolute Error :  1.75
