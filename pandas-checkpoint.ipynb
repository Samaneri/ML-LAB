# %%
import pandas as pd
import numpy as np

data = np.array([1,2,3,4,5])

s = pd.Series(data)

print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int32

# %%
import pandas as pd

df = pd.read_csv("sample.csv")

print(df)
# Out:
#    id        first       last  gender  Marks  selected
# 0   1        Leone    Debrick  Female     50      True
# 1   2       Romola  Phinnessy  Female     60     False
# 2   3         Geri      Prium    Male     65     False
# 3   4        Sandy   Doveston  Female     95     False
# 4   5      Jacenta     Jansik  Female     31      True
# 5   6  Diane-marie   Medhurst  Female     45      True
# 6   7       Austen       Pool    Male     45      True
# 7   8        Vanya    Teffrey    Male     70     False
# 8   9     Giordano      Elloy    Male     36     False
# 9  10       Rozele    Fawcett  Female     50     False

# %%
import pandas as pd
import seaborn as sns

df = sns.load_dataset("tips")

print(df.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import pandas as pd

data = [[100,37],
        [101,40],
        [102,42],
        [103,57],
        [104,60]]

df = pd.DataFrame(data, columns=["Reg No","Marks"])

print(df)
# Out:
#    Reg No  Marks
# 0     100     37
# 1     101     40
# 2     102     42
# 3     103     57
# 4     104     60

# %%
import pandas as pd

df = pd.DataFrame({
    "Marks1":[37,40,42,57,60],
    "Marks2":[40,42,43,58,67]
})

df["Total"] = df["Marks1"] + df["Marks2"]

print(df)
# Out:
#    Marks1  Marks2  Total
# 0      37      40     77
# 1      40      42     82
# 2      42      43     85
# 3      57      58    115
# 4      60      67    127

# %%
import pandas as pd

df = pd.DataFrame({
    "Marks1":[37,40,42],
    "Marks2":[40,42,43]
})

del df["Marks1"]

print(df)
# Out:
#    Marks2
# 0      40
# 1      42
# 2      43

# %%
import pandas as pd

df = pd.DataFrame({
    "Marks1":[37,40,42,57,60],
    "Marks2":[40,42,43,58,67]
})

print(df.sum())
# Out:
# Marks1    236
# Marks2    250
# dtype: int64

# %%
import pandas as pd

df = pd.DataFrame({
    "Marks1":[37,40,42,57,60],
    "Marks2":[40,42,43,58,67]
})

print(df.mean())
# Out:
# Marks1    47.2
# Marks2    50.0
# dtype: float64

# %%
import pandas as pd

df = pd.DataFrame({
    "Marks1":[37,40,42,57,60],
    "Marks2":[40,42,43,58,67]
})

print(df.std())
# Out:
# Marks1    10.521407
# Marks2    11.895377
# dtype: float64

# %%
import pandas as pd

df = pd.DataFrame({
    "Marks":[40,45,40,60,70]
})

print(df.mode())
# Out:
#    Marks
# 0     40

# %%
import pandas as pd

df = pd.DataFrame({
    "Marks":[37,40,42,57,60]
})

print(df.min())
# Out:
# Marks    37
# dtype: int64

# %%
import pandas as pd

df = pd.DataFrame({
    "Marks":[37,40,42,57,60]
})

print(df.max())
# Out:
# Marks    60
# dtype: int64

# %%
import pandas as pd

df = pd.DataFrame({
    "Values":[1,2,3,4]
})

print(df.prod())
# Out:
# Values    24
# dtype: int64

# %%
import pandas as pd

df = pd.DataFrame({
    "Values":[10,20,30,40]
})

print(df.cumsum())
import pandas as pd

df = pd.DataFrame({
    "Values":[1,2,3,4]
})

print(df.cumprod())
# Out:
#    Values
# 0      10
# 1      30
# 2      60
# 3     100
#    Values
# 0       1
# 1       2
# 2       6
# 3      24

# %%
import pandas as pd

df = pd.DataFrame({
    "Marks":[37,40,42,57,60]
})

print(df.describe())
# Out:
#            Marks
# count   5.000000
# mean   47.200000
# std    10.521407
# min    37.000000
# 25%    40.000000
# 50%    42.000000
# 75%    57.000000
# max    60.000000

# %%
import pandas as pd

s1 = pd.Series([1,2,3,4,5])
s2 = pd.Series([4,3,6,7,8])

print(s1.cov(s2))
# Out:
# 3.0

# %%
import pandas as pd

s1 = pd.Series([1,2,3,4,5])
s2 = pd.Series([4,3,6,7,8])

print(s1.corr(s2))
# Out:
# 0.914991421995628

# %%
import pandas as pd

data = {
    "Department":["IT","IT","CSE","CSE"],
    "Marks":[80,90,85,95]
}

df = pd.DataFrame(data)

print(df.groupby("Department").sum())
# Out:
#             Marks
# Department
# CSE           180
# IT            170

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.DataFrame(np.random.rand(5,2), columns=["Mark1","Mark2"])

df.plot.bar()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.DataFrame(np.random.rand(100,1), columns=["Marks"])

df.plot.hist(bins=5)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.DataFrame(np.random.rand(20,2), columns=["Mark1","Mark2"])

df.plot.box()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.DataFrame(np.random.rand(10,2), columns=["Mark1","Mark2"])

df.plot.area()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.DataFrame(np.random.rand(20,2), columns=["Mark1","Mark2"])

df.plot.scatter(x="Mark1", y="Mark2")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({"Marks":[30,20,25,25]},
                  index=["A","B","C","D"])

df.plot.pie(y="Marks", autopct="%1.1f%%")

plt.show()
